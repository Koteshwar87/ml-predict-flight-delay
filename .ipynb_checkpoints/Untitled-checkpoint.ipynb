# %%
# import matplotlib as plt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
import seaborn as sb

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier

# %%
def read_airlines_data():
    airlines = pd.read_csv('airlines.csv')
    print(airlines.columns)

# %%
def read_airports_data():
    airports = pd.read_csv('airports.csv')
    print(airports.columns)

# %%
def read_flights_data():
    flights = pd.read_csv('flights.csv', low_memory=False)
    # print(flights.columns)
    # print(flights.head())
    #flights_seg = flights[0:50000]
    flights_seg = flights.sample(n=50000, axis=0, random_state=2)
    return flights_seg

# %%
pd.set_option("display.max_columns", None)
# read_airlines_data()
# read_airports_data()
flights_seg = read_flights_data()
flights_seg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50000 entries, 1480520 to 1087005
# Data columns (total 31 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   YEAR                 50000 non-null  int64
#  1   MONTH                50000 non-null  int64
#  2   DAY                  50000 non-null  int64
#  3   DAY_OF_WEEK          50000 non-null  int64
#  4   AIRLINE              50000 non-null  object
#  5   FLIGHT_NUMBER        50000 non-null  int64
#  6   TAIL_NUMBER          49886 non-null  object
#  7   ORIGIN_AIRPORT       50000 non-null  object
#  8   DESTINATION_AIRPORT  50000 non-null  object
#  9   SCHEDULED_DEPARTURE  50000 non-null  int64
#  10  DEPARTURE_TIME       49231 non-null  float64
#  11  DEPARTURE_DELAY      49231 non-null  float64
#  12  TAXI_OUT             49213 non-null  float64
#  13  WHEELS_OFF           49213 non-null  float64
#  14  SCHEDULED_TIME       50000 non-null  float64
#  15  ELAPSED_TIME         49075 non-null  float64
#  16  AIR_TIME             49075 non-null  float64
#  17  DISTANCE             50000 non-null  int64
#  18  WHEELS_ON            49179 non-null  float64
#  19  TAXI_IN              49179 non-null  float64
#  20  SCHEDULED_ARRIVAL    50000 non-null  int64
#  21  ARRIVAL_TIME         49179 non-null  float64
#  22  ARRIVAL_DELAY        49075 non-null  float64
#  23  DIVERTED             50000 non-null  int64
#  24  CANCELLED            50000 non-null  int64
#  25  CANCELLATION_REASON  796 non-null    object
#  26  AIR_SYSTEM_DELAY     9125 non-null   float64
#  27  SECURITY_DELAY       9125 non-null   float64
#  28  AIRLINE_DELAY        9125 non-null   float64
#  29  LATE_AIRCRAFT_DELAY  9125 non-null   float64
#  30  WEATHER_DELAY        9125 non-null   float64
# dtypes: float64(16), int64(10), object(5)
# memory usage: 12.2+ MB

# %%
flights_seg.shape
# Out:
# (50000, 31)

# %%
flights_seg.isna().sum()
# Out:
# YEAR                       0
# MONTH                      0
# DAY                        0
# DAY_OF_WEEK                0
# AIRLINE                    0
# FLIGHT_NUMBER              0
# TAIL_NUMBER              114
# ORIGIN_AIRPORT             0
# DESTINATION_AIRPORT        0
# SCHEDULED_DEPARTURE        0
# DEPARTURE_TIME           769
# DEPARTURE_DELAY          769
# TAXI_OUT                 787
# WHEELS_OFF               787
# SCHEDULED_TIME             0
# ELAPSED_TIME             925
# AIR_TIME                 925
# DISTANCE                   0
# WHEELS_ON                821
# TAXI_IN                  821
# SCHEDULED_ARRIVAL          0
# ARRIVAL_TIME             821
# ARRIVAL_DELAY            925
# DIVERTED                   0
# CANCELLED                  0
# CANCELLATION_REASON    49204
# AIR_SYSTEM_DELAY       40875
# SECURITY_DELAY         40875
# AIRLINE_DELAY          40875
# LATE_AIRCRAFT_DELAY    40875
# WEATHER_DELAY          40875
# dtype: int64

# %%
# Ignore the columns which has more NA values
#flights_seg = flights_seg[flights_seg.columns.difference(["AIR_SYSTEM_DELAY", "SECURITY_DELAY", "AIRLINE_DELAY", "LATE_AIRCRAFT_DELAY", "WEATHER_DELAY"])]
flights_seg = flights_seg.drop('AIR_SYSTEM_DELAY', axis=1)
flights_seg = flights_seg.drop('SECURITY_DELAY', axis=1)
flights_seg = flights_seg.drop('AIRLINE_DELAY', axis=1)
flights_seg = flights_seg.drop('LATE_AIRCRAFT_DELAY', axis=1)
flights_seg = flights_seg.drop('WEATHER_DELAY', axis=1)
flights_seg = flights_seg.drop('CANCELLATION_REASON', axis=1)

flights_seg.shape
# Out:
# (50000, 25)

# %%
flights_seg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50000 entries, 1480520 to 1087005
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   YEAR                 50000 non-null  int64
#  1   MONTH                50000 non-null  int64
#  2   DAY                  50000 non-null  int64
#  3   DAY_OF_WEEK          50000 non-null  int64
#  4   AIRLINE              50000 non-null  object
#  5   FLIGHT_NUMBER        50000 non-null  int64
#  6   TAIL_NUMBER          49886 non-null  object
#  7   ORIGIN_AIRPORT       50000 non-null  object
#  8   DESTINATION_AIRPORT  50000 non-null  object
#  9   SCHEDULED_DEPARTURE  50000 non-null  int64
#  10  DEPARTURE_TIME       49231 non-null  float64
#  11  DEPARTURE_DELAY      49231 non-null  float64
#  12  TAXI_OUT             49213 non-null  float64
#  13  WHEELS_OFF           49213 non-null  float64
#  14  SCHEDULED_TIME       50000 non-null  float64
#  15  ELAPSED_TIME         49075 non-null  float64
#  16  AIR_TIME             49075 non-null  float64
#  17  DISTANCE             50000 non-null  int64
#  18  WHEELS_ON            49179 non-null  float64
#  19  TAXI_IN              49179 non-null  float64
#  20  SCHEDULED_ARRIVAL    50000 non-null  int64
#  21  ARRIVAL_TIME         49179 non-null  float64
#  22  ARRIVAL_DELAY        49075 non-null  float64
#  23  DIVERTED             50000 non-null  int64
#  24  CANCELLED            50000 non-null  int64
# dtypes: float64(11), int64(10), object(4)
# memory usage: 9.9+ MB

# %%
flights_seg["YEAR"].value_counts()
# Out:
# 2015    50000
# Name: YEAR, dtype: int64

# %%
flights_seg["MONTH"].value_counts()
# Out:
# 8     4373
# 7     4363
# 3     4322
# 6     4303
# 5     4291
# 10    4224
# 4     4184
# 9     4141
# 12    4028
# 1     4025
# 11    4005
# 2     3741
# Name: MONTH, dtype: int64

# %%
flights_seg = flights_seg.drop('YEAR', axis=1)

flights_seg.shape
# Out:
# (50000, 24)

# %%
corr = flights_seg.corr(method='pearson')

sb.set(rc = {'figure.figsize':(20,10)})
#sb.heatmap(corr, annot=True, cmap="coolwarm", linewidths=.5)
sb.heatmap(corr, annot=True, linewidths=.5, cmap="coolwarm")
# Out:
# C:\Users\91970\AppData\Local\Temp\ipykernel_12892\449016445.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = flights_seg.corr(method='pearson')
# <AxesSubplot: >

# %%
flights_seg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50000 entries, 1480520 to 1087005
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   MONTH                50000 non-null  int64
#  1   DAY                  50000 non-null  int64
#  2   DAY_OF_WEEK          50000 non-null  int64
#  3   AIRLINE              50000 non-null  object
#  4   FLIGHT_NUMBER        50000 non-null  int64
#  5   TAIL_NUMBER          49886 non-null  object
#  6   ORIGIN_AIRPORT       50000 non-null  object
#  7   DESTINATION_AIRPORT  50000 non-null  object
#  8   SCHEDULED_DEPARTURE  50000 non-null  int64
#  9   DEPARTURE_TIME       49231 non-null  float64
#  10  DEPARTURE_DELAY      49231 non-null  float64
#  11  TAXI_OUT             49213 non-null  float64
#  12  WHEELS_OFF           49213 non-null  float64
#  13  SCHEDULED_TIME       50000 non-null  float64
#  14  ELAPSED_TIME         49075 non-null  float64
#  15  AIR_TIME             49075 non-null  float64
#  16  DISTANCE             50000 non-null  int64
#  17  WHEELS_ON            49179 non-null  float64
#  18  TAXI_IN              49179 non-null  float64
#  19  SCHEDULED_ARRIVAL    50000 non-null  int64
#  20  ARRIVAL_TIME         49179 non-null  float64
#  21  ARRIVAL_DELAY        49075 non-null  float64
#  22  DIVERTED             50000 non-null  int64
#  23  CANCELLED            50000 non-null  int64
# dtypes: float64(11), int64(9), object(4)
# memory usage: 9.5+ MB

# %%
flights_seg.describe()
# Out:
#               MONTH           DAY   DAY_OF_WEEK  FLIGHT_NUMBER  \
# count  50000.000000  50000.000000  50000.000000   50000.000000
# mean       6.518140     15.661780      3.925980    2179.639620
# std        3.402455      8.779426      1.983023    1756.368941
# min        1.000000      1.000000      1.000000       1.000000
# 25%        4.000000      8.000000      2.000000     734.750000
# 50%        7.000000     16.000000      4.000000    1700.500000
# 75%        9.000000     23.000000      6.000000    3243.000000
# max       12.000000     31.000000      7.000000    7438.000000
#
#        SCHEDULED_DEPARTURE  DEPARTURE_TIME  DEPARTURE_DELAY      TAXI_OUT  \
# count         50000.000000    49231.000000     49231.000000  49213.000000
# mean           1325.731360     1331.561963         9.279519     16.068031
# std             482.401709      495.109400        36.729487      8.859360
# min               3.000000        1.000000       -36.000000      1.000000
# 25%             915.000000      919.000000        -5.000000     11.000000
# 50%            1318.000000     1324.000000        -2.000000     14.000000
# 75%            1730.000000     1737.000000         7.000000     19.000000
# max            2359.000000     2400.000000      1255.000000    140.000000
#
#          WHEELS_OFF  SCHEDULED_TIME  ELAPSED_TIME      AIR_TIME      DISTANCE  \
# count  49213.000000    50000.000000  49075.000000  49075.000000  50000.000000
# mean    1353.157844      141.366560    136.744228    113.240000    819.510720
# std      496.736958       75.038484     74.047132     72.036808    605.865048
# min        1.000000       20.000000     22.000000      8.000000     31.000000
# 25%      934.000000       85.000000     82.000000     60.000000    372.000000
# 50%     1336.000000      122.000000    118.000000     94.000000    646.000000
# 75%     1752.000000      173.000000    168.000000    143.000000   1055.000000
# max     2400.000000      718.000000    706.000000    658.000000   4983.000000
#
#           WHEELS_ON       TAXI_IN  SCHEDULED_ARRIVAL  ARRIVAL_TIME  \
# count  49179.000000  49179.000000       50000.000000  49179.000000
# mean    1464.497102      7.452998        1488.917120   1470.408792
# std      523.091505      5.828601         507.475168    526.677032
# min        1.000000      1.000000           1.000000      1.000000
# 25%     1052.000000      4.000000        1107.000000   1056.000000
# 50%     1500.000000      6.000000        1513.000000   1504.000000
# 75%     1910.000000      9.000000        1916.000000   1915.000000
# max     2400.000000    180.000000        2359.000000   2400.000000
#
#        ARRIVAL_DELAY      DIVERTED     CANCELLED
# count   49075.000000  50000.000000  50000.000000
# mean        4.329924      0.002580      0.015920
# std        39.080557      0.050729      0.125167
# min       -70.000000      0.000000      0.000000
# 25%       -13.000000      0.000000      0.000000
# 50%        -5.000000      0.000000      0.000000
# 75%         8.000000      0.000000      0.000000
# max      1247.000000      1.000000      1.000000

# %%
result=[]
for row in flights_seg['ARRIVAL_DELAY']:
  if row > 15:
    result.append(1)
  else:
    result.append(0)

# %%
flights_seg['RESULT'] = result

# %%
flights_seg.describe()
# Out:
#               MONTH           DAY   DAY_OF_WEEK  FLIGHT_NUMBER  \
# count  50000.000000  50000.000000  50000.000000   50000.000000
# mean       6.518140     15.661780      3.925980    2179.639620
# std        3.402455      8.779426      1.983023    1756.368941
# min        1.000000      1.000000      1.000000       1.000000
# 25%        4.000000      8.000000      2.000000     734.750000
# 50%        7.000000     16.000000      4.000000    1700.500000
# 75%        9.000000     23.000000      6.000000    3243.000000
# max       12.000000     31.000000      7.000000    7438.000000
#
#        SCHEDULED_DEPARTURE  DEPARTURE_TIME  DEPARTURE_DELAY      TAXI_OUT  \
# count         50000.000000    49231.000000     49231.000000  49213.000000
# mean           1325.731360     1331.561963         9.279519     16.068031
# std             482.401709      495.109400        36.729487      8.859360
# min               3.000000        1.000000       -36.000000      1.000000
# 25%             915.000000      919.000000        -5.000000     11.000000
# 50%            1318.000000     1324.000000        -2.000000     14.000000
# 75%            1730.000000     1737.000000         7.000000     19.000000
# max            2359.000000     2400.000000      1255.000000    140.000000
#
#          WHEELS_OFF  SCHEDULED_TIME  ELAPSED_TIME      AIR_TIME      DISTANCE  \
# count  49213.000000    50000.000000  49075.000000  49075.000000  50000.000000
# mean    1353.157844      141.366560    136.744228    113.240000    819.510720
# std      496.736958       75.038484     74.047132     72.036808    605.865048
# min        1.000000       20.000000     22.000000      8.000000     31.000000
# 25%      934.000000       85.000000     82.000000     60.000000    372.000000
# 50%     1336.000000      122.000000    118.000000     94.000000    646.000000
# 75%     1752.000000      173.000000    168.000000    143.000000   1055.000000
# max     2400.000000      718.000000    706.000000    658.000000   4983.000000
#
#           WHEELS_ON       TAXI_IN  SCHEDULED_ARRIVAL  ARRIVAL_TIME  \
# count  49179.000000  49179.000000       50000.000000  49179.000000
# mean    1464.497102      7.452998        1488.917120   1470.408792
# std      523.091505      5.828601         507.475168    526.677032
# min        1.000000      1.000000           1.000000      1.000000
# 25%     1052.000000      4.000000        1107.000000   1056.000000
# 50%     1500.000000      6.000000        1513.000000   1504.000000
# 75%     1910.000000      9.000000        1916.000000   1915.000000
# max     2400.000000    180.000000        2359.000000   2400.000000
#
#        ARRIVAL_DELAY      DIVERTED     CANCELLED        RESULT
# count   49075.000000  50000.000000  50000.000000  50000.000000
# mean        4.329924      0.002580      0.015920      0.175980
# std        39.080557      0.050729      0.125167      0.380807
# min       -70.000000      0.000000      0.000000      0.000000
# 25%       -13.000000      0.000000      0.000000      0.000000
# 50%        -5.000000      0.000000      0.000000      0.000000
# 75%         8.000000      0.000000      0.000000      0.000000
# max      1247.000000      1.000000      1.000000      1.000000

# %%
flights_seg['RESULT'].value_counts()
# Out:
# 0    41201
# 1     8799
# Name: RESULT, dtype: int64

# %%
# Removing TAXI_OUT TAXI_IN columns
flights_seg = flights_seg.drop('TAXI_OUT', axis=1)
flights_seg = flights_seg.drop('TAXI_IN', axis=1)

# %%
# DIVERTED
flights_seg['DIVERTED'].value_counts()
# Out:
# 0    49871
# 1      129
# Name: DIVERTED, dtype: int64

# %%
# CANCELLED
flights_seg['CANCELLED'].value_counts()
# Out:
# 0    49204
# 1      796
# Name: CANCELLED, dtype: int64

# %%
flights_seg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50000 entries, 1480520 to 1087005
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   MONTH                50000 non-null  int64
#  1   DAY                  50000 non-null  int64
#  2   DAY_OF_WEEK          50000 non-null  int64
#  3   AIRLINE              50000 non-null  object
#  4   FLIGHT_NUMBER        50000 non-null  int64
#  5   TAIL_NUMBER          49886 non-null  object
#  6   ORIGIN_AIRPORT       50000 non-null  object
#  7   DESTINATION_AIRPORT  50000 non-null  object
#  8   SCHEDULED_DEPARTURE  50000 non-null  int64
#  9   DEPARTURE_TIME       49231 non-null  float64
#  10  DEPARTURE_DELAY      49231 non-null  float64
#  11  WHEELS_OFF           49213 non-null  float64
#  12  SCHEDULED_TIME       50000 non-null  float64
#  13  ELAPSED_TIME         49075 non-null  float64
#  14  AIR_TIME             49075 non-null  float64
#  15  DISTANCE             50000 non-null  int64
#  16  WHEELS_ON            49179 non-null  float64
#  17  SCHEDULED_ARRIVAL    50000 non-null  int64
#  18  ARRIVAL_TIME         49179 non-null  float64
#  19  ARRIVAL_DELAY        49075 non-null  float64
#  20  DIVERTED             50000 non-null  int64
#  21  CANCELLED            50000 non-null  int64
#  22  RESULT               50000 non-null  int64
# dtypes: float64(9), int64(10), object(4)
# memory usage: 9.2+ MB

# %%
flights_seg.dropna(inplace=True)

# %%
flights_seg.shape
# Out:
# (49075, 23)

# %%
# Check for missing values
flights_seg.isnull().sum()
# Out:
# MONTH                  0
# DAY                    0
# DAY_OF_WEEK            0
# AIRLINE                0
# FLIGHT_NUMBER          0
# TAIL_NUMBER            0
# ORIGIN_AIRPORT         0
# DESTINATION_AIRPORT    0
# SCHEDULED_DEPARTURE    0
# DEPARTURE_TIME         0
# DEPARTURE_DELAY        0
# WHEELS_OFF             0
# SCHEDULED_TIME         0
# ELAPSED_TIME           0
# AIR_TIME               0
# DISTANCE               0
# WHEELS_ON              0
# SCHEDULED_ARRIVAL      0
# ARRIVAL_TIME           0
# ARRIVAL_DELAY          0
# DIVERTED               0
# CANCELLED              0
# RESULT                 0
# dtype: int64

# %%
# Exploratory data analysis

def eda(df):
    if isinstance(df, pd.DataFrame):
        total_na = df.isna().sum().sum()
        print("Dimensions : %d rows, %d columns" % (df.shape[0], df.shape[1]))
        print("Total NA Values : %d " % (total_na))
        print("%38s %10s     %10s %10s" % ("Column Name", "Data Type", "#Distinct", "NA Values"))
        col_name = df.columns
        dtyp = df.dtypes
        uniq = df.nunique()
        na_val = df.isna().sum()
        for i in range(len(df.columns)):
            print("%38s %10s   %10s %10s" % (col_name[i], dtyp[i], uniq[i], na_val[i]))
    else:
        print("Expect a DataFrame but got a %15s" % (type(df)))

# %%
eda(flights_seg)
# Out:
# Dimensions : 49075 rows, 23 columns
# Total NA Values : 0
#                            Column Name  Data Type      #Distinct  NA Values
#                                  MONTH      int64           12          0
#                                    DAY      int64           31          0
#                            DAY_OF_WEEK      int64            7          0
#                                AIRLINE     object           14          0
#                          FLIGHT_NUMBER      int64         6089          0
#                            TAIL_NUMBER     object         4506          0
#                         ORIGIN_AIRPORT     object          564          0
#                    DESTINATION_AIRPORT     object          552          0
#                    SCHEDULED_DEPARTURE      int64         1170          0
#                         DEPARTURE_TIME    float64         1270          0
#                        DEPARTURE_DELAY    float64          391          0
#                             WHEELS_OFF    float64         1280          0
#                         SCHEDULED_TIME    float64          439          0
#                           ELAPSED_TIME    float64          462          0
#                               AIR_TIME    float64          442          0
#                               DISTANCE      int64         1279          0
#                              WHEELS_ON    float64         1364          0
#                      SCHEDULED_ARRIVAL      int64         1294          0
#                           ARRIVAL_TIME    float64         1364          0
#                          ARRIVAL_DELAY    float64          424          0
#                               DIVERTED      int64            1          0
#                              CANCELLED      int64            1          0
#                                 RESULT      int64            2          0

# %%
# Drop TAIL_NUMBER, categorical variable with many values

flights_seg.drop(["TAIL_NUMBER"], inplace=True, axis=1)

# %%
categorical = [var for var in flights_seg.columns if flights_seg[var].dtype=='O']

print('There are {} categorical variables\n'.format(len(categorical)))

print('The categorical variables are :\n\n', categorical)
# Out:
# There are 3 categorical variables
#
# The categorical variables are :
#
#  ['AIRLINE', 'ORIGIN_AIRPORT', 'DESTINATION_AIRPORT']

# %%
flights_seg[categorical].head()
# Out:
#         AIRLINE ORIGIN_AIRPORT DESTINATION_AIRPORT
# 1480520      DL            JFK                 SLC
# 2454742      AA            STL                 ORD
# 2688747      AA            IAH                 DFW
# 4181017      OO            CVG                 BNA
# 5101593      WN            DAL                 OMA

# %%
# Frequency distribution of categorical variables

for var in categorical:
    print(flights_seg[var].value_counts())
# Out:
# WN    10789
# DL     7612
# AA     6064
# OO     4997
# EV     4726
# UA     4289
# MQ     2353
# B6     2248
# US     1646
# AS     1423
# NK     1010
# F9      787
# HA      610
# VX      521
# Name: AIRLINE, dtype: int64
# ATL      3030
# ORD      2367
# DFW      2000
# DEN      1692
# LAX      1564
#          ...
# 10434       1
# 11252       1
# 10990       1
# 12007       1
# 10731       1
# Name: ORIGIN_AIRPORT, Length: 564, dtype: int64
# ATL      2951
# ORD      2354
# DFW      1974
# DEN      1689
# LAX      1555
#          ...
# 11203       1
# 14489       1
# 15048       1
# 14842       1
# 12519       1
# Name: DESTINATION_AIRPORT, Length: 552, dtype: int64

# %%
for var in categorical:
    print(flights_seg[var].value_counts())
# Out:
# WN    10789
# DL     7612
# AA     6064
# OO     4997
# EV     4726
# UA     4289
# MQ     2353
# B6     2248
# US     1646
# AS     1423
# NK     1010
# F9      787
# HA      610
# VX      521
# Name: AIRLINE, dtype: int64
# ATL      3030
# ORD      2367
# DFW      2000
# DEN      1692
# LAX      1564
#          ...
# 10434       1
# 11252       1
# 10990       1
# 12007       1
# 10731       1
# Name: ORIGIN_AIRPORT, Length: 564, dtype: int64
# ATL      2951
# ORD      2354
# DFW      1974
# DEN      1689
# LAX      1555
#          ...
# 11203       1
# 14489       1
# 15048       1
# 14842       1
# 12519       1
# Name: DESTINATION_AIRPORT, Length: 552, dtype: int64

# %%
for var in categorical:
    print(var, ' contains ', len(flights_seg[var].unique()), ' labels')
# Out:
# AIRLINE  contains  14  labels
# ORIGIN_AIRPORT  contains  564  labels
# DESTINATION_AIRPORT  contains  552  labels

# %%
# Numerical features
numerical = [var for var in flights_seg.columns if flights_seg[var].dtype!='O']

print('There are {} numerical variables\n'.format(len(numerical)))

print('The numerical variables are :\n\n', numerical)
# Out:
# There are 19 numerical variables
#
# The numerical variables are :
#
#  ['MONTH', 'DAY', 'DAY_OF_WEEK', 'FLIGHT_NUMBER', 'SCHEDULED_DEPARTURE', 'DEPARTURE_TIME', 'DEPARTURE_DELAY', 'WHEELS_OFF', 'SCHEDULED_TIME', 'ELAPSED_TIME', 'AIR_TIME', 'DISTANCE', 'WHEELS_ON', 'SCHEDULED_ARRIVAL', 'ARRIVAL_TIME', 'ARRIVAL_DELAY', 'DIVERTED', 'CANCELLED', 'RESULT']

# %%
numerical
# Out:
# ['MONTH',
#  'DAY',
#  'DAY_OF_WEEK',
#  'FLIGHT_NUMBER',
#  'SCHEDULED_DEPARTURE',
#  'DEPARTURE_TIME',
#  'DEPARTURE_DELAY',
#  'WHEELS_OFF',
#  'SCHEDULED_TIME',
#  'ELAPSED_TIME',
#  'AIR_TIME',
#  'DISTANCE',
#  'WHEELS_ON',
#  'SCHEDULED_ARRIVAL',
#  'ARRIVAL_TIME',
#  'ARRIVAL_DELAY',
#  'DIVERTED',
#  'CANCELLED',
#  'RESULT']

# %%
flights_seg.describe().T
# Out:
#                        count         mean          std   min     25%     50%  \
# MONTH                49075.0     6.546898     3.393477   1.0     4.0     7.0
# DAY                  49075.0    15.665084     8.768196   1.0     8.0    16.0
# DAY_OF_WEEK          49075.0     3.929149     1.980365   1.0     2.0     4.0
# FLIGHT_NUMBER        49075.0  2169.572756  1753.764867   1.0   731.0  1691.0
# SCHEDULED_DEPARTURE  49075.0  1325.575813   482.116229   3.0   915.0  1316.0
# DEPARTURE_TIME       49075.0  1331.552298   495.196972   1.0   919.0  1324.0
# DEPARTURE_DELAY      49075.0     9.228650    36.680411 -36.0    -5.0    -2.0
# WHEELS_OFF           49075.0  1353.202241   496.815607   1.0   934.0  1336.0
# SCHEDULED_TIME       49075.0   141.642955    75.160400  20.0    85.0   122.0
# ELAPSED_TIME         49075.0   136.744228    74.047132  22.0    82.0   118.0
# AIR_TIME             49075.0   113.240000    72.036808   8.0    60.0    94.0
# DISTANCE             49075.0   822.166460   606.825240  31.0   373.0   649.0
# WHEELS_ON            49075.0  1464.336893   522.846963   1.0  1052.0  1500.0
# SCHEDULED_ARRIVAL    49075.0  1488.563240   507.239818   1.0  1108.0  1512.0
# ARRIVAL_TIME         49075.0  1470.409210   526.342375   1.0  1056.0  1504.0
# ARRIVAL_DELAY        49075.0     4.329924    39.080557 -70.0   -13.0    -5.0
# DIVERTED             49075.0     0.000000     0.000000   0.0     0.0     0.0
# CANCELLED            49075.0     0.000000     0.000000   0.0     0.0     0.0
# RESULT               49075.0     0.179297     0.383605   0.0     0.0     0.0
#
#                         75%     max
# MONTH                   9.0    12.0
# DAY                    23.0    31.0
# DAY_OF_WEEK             6.0     7.0
# FLIGHT_NUMBER        3223.0  7438.0
# SCHEDULED_DEPARTURE  1730.0  2359.0
# DEPARTURE_TIME       1738.0  2400.0
# DEPARTURE_DELAY         7.0  1255.0
# WHEELS_OFF           1752.0  2400.0
# SCHEDULED_TIME        173.0   718.0
# ELAPSED_TIME          168.0   706.0
# AIR_TIME              143.0   658.0
# DISTANCE             1062.0  4983.0
# WHEELS_ON            1910.0  2400.0
# SCHEDULED_ARRIVAL    1915.0  2359.0
# ARRIVAL_TIME         1915.0  2400.0
# ARRIVAL_DELAY           8.0  1247.0
# DIVERTED                0.0     0.0
# CANCELLED               0.0     0.0
# RESULT                  0.0     1.0

# %%
flights_seg[numerical].isnull().sum()
# Out:
# MONTH                  0
# DAY                    0
# DAY_OF_WEEK            0
# FLIGHT_NUMBER          0
# SCHEDULED_DEPARTURE    0
# DEPARTURE_TIME         0
# DEPARTURE_DELAY        0
# WHEELS_OFF             0
# SCHEDULED_TIME         0
# ELAPSED_TIME           0
# AIR_TIME               0
# DISTANCE               0
# WHEELS_ON              0
# SCHEDULED_ARRIVAL      0
# ARRIVAL_TIME           0
# ARRIVAL_DELAY          0
# DIVERTED               0
# CANCELLED              0
# RESULT                 0
# dtype: int64

# %%
# Airline to Arrival delay analysis (Categorical variable to Numeric variable)

f, ax = plt.subplots(figsize=(35, 15))
ax = sb.boxplot(x="AIRLINE", y="ARRIVAL_DELAY", data=flights_seg)
ax.set_title("Visualize DISTANCE wrt ARRIVAL_DELAY variable")
plt.show()

# %%
flights_seg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49075 entries, 1480520 to 1087005
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   MONTH                49075 non-null  int64
#  1   DAY                  49075 non-null  int64
#  2   DAY_OF_WEEK          49075 non-null  int64
#  3   AIRLINE              49075 non-null  object
#  4   FLIGHT_NUMBER        49075 non-null  int64
#  5   ORIGIN_AIRPORT       49075 non-null  object
#  6   DESTINATION_AIRPORT  49075 non-null  object
#  7   SCHEDULED_DEPARTURE  49075 non-null  int64
#  8   DEPARTURE_TIME       49075 non-null  float64
#  9   DEPARTURE_DELAY      49075 non-null  float64
#  10  WHEELS_OFF           49075 non-null  float64
#  11  SCHEDULED_TIME       49075 non-null  float64
#  12  ELAPSED_TIME         49075 non-null  float64
#  13  AIR_TIME             49075 non-null  float64
#  14  DISTANCE             49075 non-null  int64
#  15  WHEELS_ON            49075 non-null  float64
#  16  SCHEDULED_ARRIVAL    49075 non-null  int64
#  17  ARRIVAL_TIME         49075 non-null  float64
#  18  ARRIVAL_DELAY        49075 non-null  float64
#  19  DIVERTED             49075 non-null  int64
#  20  CANCELLED            49075 non-null  int64
#  21  RESULT               49075 non-null  int64
# dtypes: float64(9), int64(10), object(3)
# memory usage: 8.6+ MB

# %%
flights_seg_bkp = flights_seg

# %%
# Encoding categorical data using One Hot Encoding
# ['AIRLINE', 'ORIGIN_AIRPORT', 'DESTINATION_AIRPORT']

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# %%
#ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [3])], remainder='passthrough')
#transformed_data = np.array(ct.fit_transform(flights_seg))

# the above transformed_data is an array so convert it to dataframe
#encoded_data = pd.DataFrame(transformed_data, index=flights_seg.index)

# %%
flights_seg = pd.get_dummies(flights_seg, columns=['AIRLINE'])

# %%
# now concatenate the original data and the encoded data using pandas
#flights_seg = pd.concat([flights_seg, encoded_data], axis=1)

# %%
flights_seg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49075 entries, 1480520 to 1087005
# Data columns (total 35 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   MONTH                49075 non-null  int64
#  1   DAY                  49075 non-null  int64
#  2   DAY_OF_WEEK          49075 non-null  int64
#  3   FLIGHT_NUMBER        49075 non-null  int64
#  4   ORIGIN_AIRPORT       49075 non-null  object
#  5   DESTINATION_AIRPORT  49075 non-null  object
#  6   SCHEDULED_DEPARTURE  49075 non-null  int64
#  7   DEPARTURE_TIME       49075 non-null  float64
#  8   DEPARTURE_DELAY      49075 non-null  float64
#  9   WHEELS_OFF           49075 non-null  float64
#  10  SCHEDULED_TIME       49075 non-null  float64
#  11  ELAPSED_TIME         49075 non-null  float64
#  12  AIR_TIME             49075 non-null  float64
#  13  DISTANCE             49075 non-null  int64
#  14  WHEELS_ON            49075 non-null  float64
#  15  SCHEDULED_ARRIVAL    49075 non-null  int64
#  16  ARRIVAL_TIME         49075 non-null  float64
#  17  ARRIVAL_DELAY        49075 non-null  float64
#  18  DIVERTED             49075 non-null  int64
#  19  CANCELLED            49075 non-null  int64
#  20  RESULT               49075 non-null  int64
#  21  AIRLINE_AA           49075 non-null  uint8
#  22  AIRLINE_AS           49075 non-null  uint8
#  23  AIRLINE_B6           49075 non-null  uint8
#  24  AIRLINE_DL           49075 non-null  uint8
#  25  AIRLINE_EV           49075 non-null  uint8
#  26  AIRLINE_F9           49075 non-null  uint8
#  27  AIRLINE_HA           49075 non-null  uint8
#  28  AIRLINE_MQ           49075 non-null  uint8
#  29  AIRLINE_NK           49075 non-null  uint8
#  30  AIRLINE_OO           49075 non-null  uint8
#  31  AIRLINE_UA           49075 non-null  uint8
#  32  AIRLINE_US           49075 non-null  uint8
#  33  AIRLINE_VX           49075 non-null  uint8
#  34  AIRLINE_WN           49075 non-null  uint8
# dtypes: float64(9), int64(10), object(2), uint8(14)
# memory usage: 8.9+ MB

# %%
# Find the top 10 most frequent categories for column 'ORIGIN_AIRPORT'
flights_seg.ORIGIN_AIRPORT.value_counts().sort_values(ascending = False).head(15)
# Out:
# ATL    3030
# ORD    2367
# DFW    2000
# DEN    1692
# LAX    1564
# IAH    1246
# PHX    1204
# SFO    1156
# LAS    1135
# MSP    1004
# SEA     933
# MCO     927
# DTW     880
# CLT     877
# EWR     869
# Name: ORIGIN_AIRPORT, dtype: int64

# %%
# make a list of the most frequent categories of the column
top_10_occurring_cat = [cat for cat in flights_seg.ORIGIN_AIRPORT.value_counts().sort_values(ascending = False).head(15).index]

# %%
print(top_10_occurring_cat)
# Out:
# ['ATL', 'ORD', 'DFW', 'DEN', 'LAX', 'IAH', 'PHX', 'SFO', 'LAS', 'MSP', 'SEA', 'MCO', 'DTW', 'CLT', 'EWR']

# %%
# now make the 15 binary variables
for cat in top_10_occurring_cat:
    flights_seg[cat] = np.where(flights_seg['ORIGIN_AIRPORT'] == cat, 1, 0) # whenever flights_seg['ORIGIN_AIRPORT'] == cat replace it with 1 else 0

# %%
flights_seg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49075 entries, 1480520 to 1087005
# Data columns (total 50 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   MONTH                49075 non-null  int64
#  1   DAY                  49075 non-null  int64
#  2   DAY_OF_WEEK          49075 non-null  int64
#  3   FLIGHT_NUMBER        49075 non-null  int64
#  4   ORIGIN_AIRPORT       49075 non-null  object
#  5   DESTINATION_AIRPORT  49075 non-null  object
#  6   SCHEDULED_DEPARTURE  49075 non-null  int64
#  7   DEPARTURE_TIME       49075 non-null  float64
#  8   DEPARTURE_DELAY      49075 non-null  float64
#  9   WHEELS_OFF           49075 non-null  float64
#  10  SCHEDULED_TIME       49075 non-null  float64
#  11  ELAPSED_TIME         49075 non-null  float64
#  12  AIR_TIME             49075 non-null  float64
#  13  DISTANCE             49075 non-null  int64
#  14  WHEELS_ON            49075 non-null  float64
#  15  SCHEDULED_ARRIVAL    49075 non-null  int64
#  16  ARRIVAL_TIME         49075 non-null  float64
#  17  ARRIVAL_DELAY        49075 non-null  float64
#  18  DIVERTED             49075 non-null  int64
#  19  CANCELLED            49075 non-null  int64
#  20  RESULT               49075 non-null  int64
#  21  AIRLINE_AA           49075 non-null  uint8
#  22  AIRLINE_AS           49075 non-null  uint8
#  23  AIRLINE_B6           49075 non-null  uint8
#  24  AIRLINE_DL           49075 non-null  uint8
#  25  AIRLINE_EV           49075 non-null  uint8
#  26  AIRLINE_F9           49075 non-null  uint8
#  27  AIRLINE_HA           49075 non-null  uint8
#  28  AIRLINE_MQ           49075 non-null  uint8
#  29  AIRLINE_NK           49075 non-null  uint8
#  30  AIRLINE_OO           49075 non-null  uint8
#  31  AIRLINE_UA           49075 non-null  uint8
#  32  AIRLINE_US           49075 non-null  uint8
#  33  AIRLINE_VX           49075 non-null  uint8
#  34  AIRLINE_WN           49075 non-null  uint8
#  35  ATL                  49075 non-null  int32
#  36  ORD                  49075 non-null  int32
#  37  DFW                  49075 non-null  int32
#  38  DEN                  49075 non-null  int32
#  39  LAX                  49075 non-null  int32
#  40  IAH                  49075 non-null  int32
#  41  PHX                  49075 non-null  int32
#  42  SFO                  49075 non-null  int32
#  43  LAS                  49075 non-null  int32
#  44  MSP                  49075 non-null  int32
#  45  SEA                  49075 non-null  int32
#  46  MCO                  49075 non-null  int32
#  47  DTW                  49075 non-null  int32
#  48  CLT                  49075 non-null  int32
#  49  EWR                  49075 non-null  int32
# dtypes: float64(9), int32(15), int64(10), object(2), uint8(14)
# memory usage: 11.7+ MB

# %%
flights_seg.DESTINATION_AIRPORT.value_counts().sort_values(ascending = False).head(15)
# Out:
# ATL    2951
# ORD    2354
# DFW    1974
# DEN    1689
# LAX    1555
# SFO    1269
# PHX    1247
# IAH    1223
# LAS    1153
# MCO     990
# MSP     974
# DTW     970
# BOS     911
# SEA     889
# JFK     860
# Name: DESTINATION_AIRPORT, dtype: int64

# %%
top_10_occurring_cat = [cat for cat in flights_seg.DESTINATION_AIRPORT.value_counts().sort_values(ascending = False).head(15).index]

# %%
print(top_10_occurring_cat)
# Out:
# ['ATL', 'ORD', 'DFW', 'DEN', 'LAX', 'SFO', 'PHX', 'IAH', 'LAS', 'MCO', 'MSP', 'DTW', 'BOS', 'SEA', 'JFK']

# %%
# now make the 15 binary variables
for cat in top_10_occurring_cat:
    flights_seg[cat] = np.where(flights_seg['DESTINATION_AIRPORT'] == cat, 1, 0) # whenever flights_seg['DESTINATION_AIRPORT'] == cat replace it with 1 else 0

# %%
flights_seg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49075 entries, 1480520 to 1087005
# Data columns (total 52 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   MONTH                49075 non-null  int64
#  1   DAY                  49075 non-null  int64
#  2   DAY_OF_WEEK          49075 non-null  int64
#  3   FLIGHT_NUMBER        49075 non-null  int64
#  4   ORIGIN_AIRPORT       49075 non-null  object
#  5   DESTINATION_AIRPORT  49075 non-null  object
#  6   SCHEDULED_DEPARTURE  49075 non-null  int64
#  7   DEPARTURE_TIME       49075 non-null  float64
#  8   DEPARTURE_DELAY      49075 non-null  float64
#  9   WHEELS_OFF           49075 non-null  float64
#  10  SCHEDULED_TIME       49075 non-null  float64
#  11  ELAPSED_TIME         49075 non-null  float64
#  12  AIR_TIME             49075 non-null  float64
#  13  DISTANCE             49075 non-null  int64
#  14  WHEELS_ON            49075 non-null  float64
#  15  SCHEDULED_ARRIVAL    49075 non-null  int64
#  16  ARRIVAL_TIME         49075 non-null  float64
#  17  ARRIVAL_DELAY        49075 non-null  float64
#  18  DIVERTED             49075 non-null  int64
#  19  CANCELLED            49075 non-null  int64
#  20  RESULT               49075 non-null  int64
#  21  AIRLINE_AA           49075 non-null  uint8
#  22  AIRLINE_AS           49075 non-null  uint8
#  23  AIRLINE_B6           49075 non-null  uint8
#  24  AIRLINE_DL           49075 non-null  uint8
#  25  AIRLINE_EV           49075 non-null  uint8
#  26  AIRLINE_F9           49075 non-null  uint8
#  27  AIRLINE_HA           49075 non-null  uint8
#  28  AIRLINE_MQ           49075 non-null  uint8
#  29  AIRLINE_NK           49075 non-null  uint8
#  30  AIRLINE_OO           49075 non-null  uint8
#  31  AIRLINE_UA           49075 non-null  uint8
#  32  AIRLINE_US           49075 non-null  uint8
#  33  AIRLINE_VX           49075 non-null  uint8
#  34  AIRLINE_WN           49075 non-null  uint8
#  35  ATL                  49075 non-null  int32
#  36  ORD                  49075 non-null  int32
#  37  DFW                  49075 non-null  int32
#  38  DEN                  49075 non-null  int32
#  39  LAX                  49075 non-null  int32
#  40  IAH                  49075 non-null  int32
#  41  PHX                  49075 non-null  int32
#  42  SFO                  49075 non-null  int32
#  43  LAS                  49075 non-null  int32
#  44  MSP                  49075 non-null  int32
#  45  SEA                  49075 non-null  int32
#  46  MCO                  49075 non-null  int32
#  47  DTW                  49075 non-null  int32
#  48  CLT                  49075 non-null  int32
#  49  EWR                  49075 non-null  int32
#  50  BOS                  49075 non-null  int32
#  51  JFK                  49075 non-null  int32
# dtypes: float64(9), int32(17), int64(10), object(2), uint8(14)
# memory usage: 12.1+ MB

# %%
X = flights_seg.iloc[:, :-1]
y = flights_seg.iloc[:, -1]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.30, random_state=0)

# %%
X_train.shape
# Out:
# (34352, 34)

# %%
X_test.shape
# Out:
# (14723, 34)

# %%
# StandardScaler is the industry's go-to algorithm. 🙂 StandardScaler standardizes a feature by subtracting the mean and then scaling to unit variance. 
# Unit variance means dividing all the values by the standard deviation. StandardScaler does not meet the strict definition of scale I introduced earlier

# All fields should be int or float to apply StandardScaler

# scaled_features = StandardScaler().fit_transform(X_train, X_test)

# %%
clf = DecisionTreeClassifier()
clf = clf.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [228], line 2
#       1 clf = DecisionTreeClassifier()
# ----> 2 clf = clf.fit(X_train,y_train)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\tree\_classes.py:969, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
#     939 def fit(self, X, y, sample_weight=None, check_input=True):
#     940     """Build a decision tree classifier from the training set (X, y).
#     941
#     942     Parameters
#    (...)
#     966         Fitted estimator.
#     967     """
# --> 969     super().fit(
#     970         X,
#     971         y,
#     972         sample_weight=sample_weight,
#     973         check_input=check_input,
#     974     )
#     975     return self
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\tree\_classes.py:172, in BaseDecisionTree.fit(self, X, y, sample_weight, check_input)
#     170 check_X_params = dict(dtype=DTYPE, accept_sparse="csc")
#     171 check_y_params = dict(ensure_2d=False, dtype=None)
# --> 172 X, y = self._validate_data(
#     173     X, y, validate_separately=(check_X_params, check_y_params)
#     174 )
#     175 if issparse(X):
#     176     X.sort_indices()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:591, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     589 if "estimator" not in check_X_params:
#     590     check_X_params = {**default_check_params, **check_X_params}
# --> 591 X = check_array(X, input_name="X", **check_X_params)
#     592 if "estimator" not in check_y_params:
#     593     check_y_params = {**default_check_params, **check_y_params}
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:856, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     854         array = array.astype(dtype, casting="unsafe", copy=False)
#     855     else:
# --> 856         array = np.asarray(array, order=order, dtype=dtype)
#     857 except ComplexWarning as complex_warning:
#     858     raise ValueError(
#     859         "Complex data not supported\n{}\n".format(array)
#     860     ) from complex_warning
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py:2069, in NDFrame.__array__(self, dtype)
#    2068 def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
# -> 2069     return np.asarray(self._values, dtype=dtype)
#
# ValueError: could not convert string to float: 'DFW'
